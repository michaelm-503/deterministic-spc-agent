# %%
import json
import random
from pathlib import Path
import sys
from IPython.display import Image, display

# ---- Project root setup ----

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# ---- Set plan filename ----

plan_filename = "test_bad_schema.json"
plan_lib = json.loads((PROJECT_ROOT / "planner" / plan_filename).read_text())

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 0

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: run_id is missing
# jobs: []
#
# Plan validation failed: Missing required key 'run_id' at run. Object keys present: ['request_text']. This key is required by the v0.2.0 schema.
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[2], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:34, in validate_run_plan(run_plan)
#      27 """
#      28 Validate one run object (not the entire library).
#      29 Expected shape:
#      30   { "run_id": str, "request_text": str, "jobs": [ ... ] }
#      31 """
#      32 _require_type(run_plan, dict, "run")
# ---> 34 _require(run_plan, "run_id", "run")
#      35 _require(run_plan, "request_text", "run")
#      36 _require(run_plan, "jobs", "run")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:14, in _require(d, key, path)
#      12 def _require(d: dict, key: str, path: str):
#      13     if key not in d:
# ---> 14         raise PlanValidationError(
#      15             f"Missing required key '{key}' at {path}. "
#      16             f"Object keys present: {sorted(d.keys())}. "
#      17             f"This key is required by the v0.2.0 schema."
#      18         )
#
# PlanValidationError: Missing required key 'run_id' at run. Object keys present: ['request_text']. This key is required by the v0.2.0 schema.

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 1

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: None
# jobs: []
#
# Plan validation failed: Missing required key 'request_text' at run. Object keys present: ['jobs', 'run_id']. This key is required by the v0.2.0 schema.
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[3], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:35, in validate_run_plan(run_plan)
#      32 _require_type(run_plan, dict, "run")
#      34 _require(run_plan, "run_id", "run")
# ---> 35 _require(run_plan, "request_text", "run")
#      36 _require(run_plan, "jobs", "run")
#      38 _require_type(run_plan["jobs"], list, "run.jobs")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:14, in _require(d, key, path)
#      12 def _require(d: dict, key: str, path: str):
#      13     if key not in d:
# ---> 14         raise PlanValidationError(
#      15             f"Missing required key '{key}' at {path}. "
#      16             f"Object keys present: {sorted(d.keys())}. "
#      17             f"This key is required by the v0.2.0 schema."
#      18         )
#
# PlanValidationError: Missing required key 'request_text' at run. Object keys present: ['jobs', 'run_id']. This key is required by the v0.2.0 schema.

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 2

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
#print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: jobs should be a list, but is a dict
#
# Plan validation failed: Expected run.jobs to be list, got dict
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[4], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:38, in validate_run_plan(run_plan)
#      35 _require(run_plan, "request_text", "run")
#      36 _require(run_plan, "jobs", "run")
# ---> 38 _require_type(run_plan["jobs"], list, "run.jobs")
#      39 if len(run_plan["jobs"]) == 0:
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:23, in _require_type(val, expected_type, path)
#      21 def _require_type(val: Any, expected_type: type, path: str):
#      22     if not isinstance(val, expected_type):
# ---> 23         raise PlanValidationError(f"Expected {path} to be {expected_type.__name__}, got {type(val).__name__}")
#
# PlanValidationError: Expected run.jobs to be list, got dict

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 3

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: job missing sql_template/preprocess/filters
# jobs: ['job_missing_sql_preprocess_filters']
#
# Plan validation failed: Missing required key 'sql_template' at run.jobs[0]. Object keys present: ['job_id']. This key is required by the v0.2.0 schema.
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[5], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:51, in validate_job(job, path)
#      49 # Required keys
#      50 for k in ["job_id", "sql_template", "preprocess", "filters"]:
# ---> 51     _require(job, k, path)
#      53 # Registry checks
#      54 sql_key = job["sql_template"]
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:14, in _require(d, key, path)
#      12 def _require(d: dict, key: str, path: str):
#      13     if key not in d:
# ---> 14         raise PlanValidationError(
#      15             f"Missing required key '{key}' at {path}. "
#      16             f"Object keys present: {sorted(d.keys())}. "
#      17             f"This key is required by the v0.2.0 schema."
#      18         )
#
# PlanValidationError: Missing required key 'sql_template' at run.jobs[0]. Object keys present: ['job_id']. This key is required by the v0.2.0 schema.

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 4

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: sql_template not in SQL_REGISTRY
# jobs: ['bad_sql_template_key']
#
# Plan validation failed: run.jobs[0].sql_template='does_not_exist_sql_template' not in SQL_REGISTRY. Valid: ['entity_sensor_history', 'fleet_sensor_history']
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[6], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:56, in validate_job(job, path)
#      54 sql_key = job["sql_template"]
#      55 if sql_key not in SQL_REGISTRY:
# ---> 56     raise PlanValidationError(
#      57         f"{path}.sql_template='{sql_key}' not in SQL_REGISTRY. "
#      58         f"Valid: {sorted(SQL_REGISTRY.keys())}"
#      59 )
#      61 preprocess_key = job["preprocess"]
#      62 if preprocess_key not in PREPROCESS_REGISTRY:
#
# PlanValidationError: run.jobs[0].sql_template='does_not_exist_sql_template' not in SQL_REGISTRY. Valid: ['entity_sensor_history', 'fleet_sensor_history']

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 5

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: preprocess not in PREPROCESS_REGISTRY
# jobs: ['bad_preprocess_key']
#
# Plan validation failed: run.jobs[0].preprocess='does_not_exist_preprocess' not in PREPROCESS_REGISTRY. Valid: ['ewma_spc']
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[7], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:63, in validate_job(job, path)
#      61 preprocess_key = job["preprocess"]
#      62 if preprocess_key not in PREPROCESS_REGISTRY:
# ---> 63     raise PlanValidationError(
#      64         f"{path}.preprocess='{preprocess_key}' not in PREPROCESS_REGISTRY. "
#      65         f"Valid: {sorted(PREPROCESS_REGISTRY.keys())}"
#      66 )
#      69 # Filters: required container; content varies by job type
#      70 _require_type(job["filters"], dict, f"{path}.filters")
#
# PlanValidationError: run.jobs[0].preprocess='does_not_exist_preprocess' not in PREPROCESS_REGISTRY. Valid: ['ewma_spc']

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 6

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: filters missing entirely
# jobs: ['no_filters']
#
# Plan validation failed: Missing required key 'filters' at run.jobs[0]. Object keys present: ['job_id', 'outputs', 'preprocess', 'sql_template']. This key is required by the v0.2.0 schema.
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[8], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:51, in validate_job(job, path)
#      49 # Required keys
#      50 for k in ["job_id", "sql_template", "preprocess", "filters"]:
# ---> 51     _require(job, k, path)
#      53 # Registry checks
#      54 sql_key = job["sql_template"]
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:14, in _require(d, key, path)
#      12 def _require(d: dict, key: str, path: str):
#      13     if key not in d:
# ---> 14         raise PlanValidationError(
#      15             f"Missing required key '{key}' at {path}. "
#      16             f"Object keys present: {sorted(d.keys())}. "
#      17             f"This key is required by the v0.2.0 schema."
#      18         )
#
# PlanValidationError: Missing required key 'filters' at run.jobs[0]. Object keys present: ['job_id', 'outputs', 'preprocess', 'sql_template']. This key is required by the v0.2.0 schema.

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 7

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: filters must be dict, but is list
# jobs: ['filters_list']
#
# Plan validation failed: Expected run.jobs[0].filters to be dict, got list
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[9], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:70, in validate_job(job, path)
#      63     raise PlanValidationError(
#      64         f"{path}.preprocess='{preprocess_key}' not in PREPROCESS_REGISTRY. "
#      65         f"Valid: {sorted(PREPROCESS_REGISTRY.keys())}"
#      66 )
#      69 # Filters: required container; content varies by job type
# ---> 70 _require_type(job["filters"], dict, f"{path}.filters")
#      72 # Outputs are optional
#      73 outputs = job.get("outputs", {})
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:23, in _require_type(val, expected_type, path)
#      21 def _require_type(val: Any, expected_type: type, path: str):
#      22     if not isinstance(val, expected_type):
# ---> 23         raise PlanValidationError(f"Expected {path} to be {expected_type.__name__}, got {type(val).__name__}")
#
# PlanValidationError: Expected run.jobs[0].filters to be dict, got list

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 8

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: outputs must be dict, but is string
# jobs: ['outputs_string']
#
# Plan validation failed: Expected run.jobs[0].outputs to be dict, got str
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[10], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:76, in validate_job(job, path)
#      74 if outputs is None:
#      75     outputs = {}
# ---> 76 _require_type(outputs, dict, f"{path}.outputs")
#      78 # Validate plots
#      79 plots = outputs.get("plots", [])
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:23, in _require_type(val, expected_type, path)
#      21 def _require_type(val: Any, expected_type: type, path: str):
#      22     if not isinstance(val, expected_type):
# ---> 23         raise PlanValidationError(f"Expected {path} to be {expected_type.__name__}, got {type(val).__name__}")
#
# PlanValidationError: Expected run.jobs[0].outputs to be dict, got str

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 9

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: outputs.plots must be list, but is dict
# jobs: ['plots_dict']
#
# Plan validation failed: Expected run.jobs[0].outputs.plots to be list, got dict
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[11], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:82, in validate_job(job, path)
#      80 if plots is None:
#      81     plots = []
# ---> 82 _require_type(plots, list, f"{path}.outputs.plots")
#      84 for j, plot_spec in enumerate(plots):
#      85     validate_plot_spec(plot_spec, path=f"{path}.outputs.plots[{j}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:23, in _require_type(val, expected_type, path)
#      21 def _require_type(val: Any, expected_type: type, path: str):
#      22     if not isinstance(val, expected_type):
# ---> 23         raise PlanValidationError(f"Expected {path} to be {expected_type.__name__}, got {type(val).__name__}")
#
# PlanValidationError: Expected run.jobs[0].outputs.plots to be list, got dict

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 10

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: plot_name missing
# jobs: ['plot_missing_plot_name']
#
# Plan validation failed: run.jobs[0].outputs.plots[0] is missing required key 'plot_name'. Each plot must define a deterministic output filename. Example:
#   { "plot": "spc_time_series", "plot_name": "example.png" }
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[12], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:85, in validate_job(job, path)
#      82 _require_type(plots, list, f"{path}.outputs.plots")
#      84 for j, plot_spec in enumerate(plots):
# ---> 85     validate_plot_spec(plot_spec, path=f"{path}.outputs.plots[{j}]")
#      87 # Validate tables (if present)
#      88 tables = outputs.get("tables", [])
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:102, in validate_plot_spec(plot_spec, path)
#      99 _require(plot_spec, "plot", path)
#     101 if "plot_name" not in plot_spec:
# --> 102     raise PlanValidationError(
#     103         f"{path} is missing required key 'plot_name'. "
#     104         f"Each plot must define a deterministic output filename. "
#     105         f"Example:\n"
#     106         f'  {{ "plot": "spc_time_series", "plot_name": "example.png" }}'
#     107     )
#     109 plot_key = plot_spec["plot"]
#     110 if plot_key not in PLOT_REGISTRY:
#
# PlanValidationError: run.jobs[0].outputs.plots[0] is missing required key 'plot_name'. Each plot must define a deterministic output filename. Example:
#   { "plot": "spc_time_series", "plot_name": "example.png" }

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 11

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: plot key not in PLOT_REGISTRY
# jobs: ['plot_bad_key']
#
# Plan validation failed: run.jobs[0].outputs.plots[0].plot='does_not_exist_plot' not in PLOT_REGISTRY. Valid: ['fleet_boxplot', 'fleet_time_trend', 'spc_time_series']
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[13], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:85, in validate_job(job, path)
#      82 _require_type(plots, list, f"{path}.outputs.plots")
#      84 for j, plot_spec in enumerate(plots):
# ---> 85     validate_plot_spec(plot_spec, path=f"{path}.outputs.plots[{j}]")
#      87 # Validate tables (if present)
#      88 tables = outputs.get("tables", [])
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:111, in validate_plot_spec(plot_spec, path)
#     109 plot_key = plot_spec["plot"]
#     110 if plot_key not in PLOT_REGISTRY:
# --> 111     raise PlanValidationError(
#     112         f"{path}.plot='{plot_key}' not in PLOT_REGISTRY. "
#     113         f"Valid: {sorted(PLOT_REGISTRY.keys())}"
#     114 )
#     116 # params optional
#     117 params = plot_spec.get("params", {})
#
# PlanValidationError: run.jobs[0].outputs.plots[0].plot='does_not_exist_plot' not in PLOT_REGISTRY. Valid: ['fleet_boxplot', 'fleet_time_trend', 'spc_time_series']

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 12

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: outputs.tables must be list, but is string
# jobs: ['tables_string']
#
# Plan validation failed: Expected run.jobs[0].outputs.tables to be list, got str
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[14], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:91, in validate_job(job, path)
#      89 if tables is None:
#      90     tables = []
# ---> 91 _require_type(tables, list, f"{path}.outputs.tables")
#      93 for j, table_spec in enumerate(tables):
#      94     validate_table_spec(table_spec, path=f"{path}.outputs.tables[{j}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:23, in _require_type(val, expected_type, path)
#      21 def _require_type(val: Any, expected_type: type, path: str):
#      22     if not isinstance(val, expected_type):
# ---> 23         raise PlanValidationError(f"Expected {path} to be {expected_type.__name__}, got {type(val).__name__}")
#
# PlanValidationError: Expected run.jobs[0].outputs.tables to be list, got str

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 13

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: table_name missing
# jobs: ['table_missing_table_name']
#
# Plan validation failed: run.jobs[0].outputs.tables[0] is missing required key 'table_name'. Each table must define a deterministic output filename. Example:
#   { "table": "fleet_ooc_summary", "table_name": "summary.csv" }
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[15], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:94, in validate_job(job, path)
#      91 _require_type(tables, list, f"{path}.outputs.tables")
#      93 for j, table_spec in enumerate(tables):
# ---> 94     validate_table_spec(table_spec, path=f"{path}.outputs.tables[{j}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:128, in validate_table_spec(table_spec, path)
#     125 _require(table_spec, "table", path)
#     127 if "table_name" not in table_spec:
# --> 128     raise PlanValidationError(
#     129         f"{path} is missing required key 'table_name'. "
#     130         f"Each table must define a deterministic output filename. "
#     131         f"Example:\n"
#     132         f'  {{ "table": "fleet_ooc_summary", "table_name": "summary.csv" }}'
#     133     )
#     135 table_key = table_spec["table"]
#     136 if table_key not in TABLE_REGISTRY:
#
# PlanValidationError: run.jobs[0].outputs.tables[0] is missing required key 'table_name'. Each table must define a deterministic output filename. Example:
#   { "table": "fleet_ooc_summary", "table_name": "summary.csv" }

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 14

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: FAIL: table key not in TABLE_REGISTRY
# jobs: ['table_bad_key']
#
# Plan validation failed: run.jobs[0].outputs.tables[0].table='does_not_exist_table' not in TABLE_REGISTRY. Valid: ['fleet_ooc_summary']
# ---------------------------------------------------------------------------
# PlanValidationError                       Traceback (most recent call last)
# Cell In[16], line 15
#      12 from runner.validate_plan import validate_run_plan, PlanValidationError
#      14 try:
# ---> 15     validate_run_plan(run_plan)
#      16 except PlanValidationError as e:
#      17     print("Plan validation failed:", e)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:43, in validate_run_plan(run_plan)
#      40     raise PlanValidationError("run.jobs must contain at least one job")
#      42 for i, job in enumerate(run_plan["jobs"]):
# ---> 43     validate_job(job, path=f"run.jobs[{i}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:94, in validate_job(job, path)
#      91 _require_type(tables, list, f"{path}.outputs.tables")
#      93 for j, table_spec in enumerate(tables):
# ---> 94     validate_table_spec(table_spec, path=f"{path}.outputs.tables[{j}]")
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/validate_plan.py:137, in validate_table_spec(table_spec, path)
#     135 table_key = table_spec["table"]
#     136 if table_key not in TABLE_REGISTRY:
# --> 137     raise PlanValidationError(
#     138         f"{path}.table='{table_key}' not in TABLE_REGISTRY. "
#     139         f"Valid: {sorted(TABLE_REGISTRY.keys())}"
#     140 )
#     143 params = table_spec.get("params", {})
#     144 if params is None:
#
# PlanValidationError: run.jobs[0].outputs.tables[0].table='does_not_exist_table' not in TABLE_REGISTRY. Valid: ['fleet_ooc_summary']

# %%
# ---- Run through each run manually to test schema fails ----

run_idx = 15

runs = plan_lib["runs"]
run_plan = runs[run_idx]

print("request_text:", run_plan.get("request_text"))
print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
print()

from runner.validate_plan import validate_run_plan, PlanValidationError

try:
    validate_run_plan(run_plan)
except PlanValidationError as e:
    print("Plan validation failed:", e)
    raise
# Out:
# request_text: TEST: Entity/Entity Group Mismatch.
# jobs: ['cnc01_vibration_spc_all_flags']

# %%
# ---- Execute one run ----

from runner.run_one_run import run_one_run

run_dir = run_one_run(run_plan, PROJECT_ROOT)
print("Run directory:", run_dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/run_one_run.py:207, in run_one_run(plan, project_root)
#     206 try:
# --> 207     execute_job(con, project_root, run_dir, job, run_id=plan.get("run_id"))
#     208 except Exception as e:
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/run_one_run.py:77, in execute_job(con, project_root, run_dir, job, run_id)
#      76 if df.empty:
# ---> 77     raise ValueError(
#      78         f"SQL returned 0 rows for run_id='{run_id}' job_id='{job['job_id']}' "
#      79         f"filters={filters} sql_template={job['sql_template']}"
#      80     )
#      82 df.to_csv(job_dir / "extracted_data.csv", index=False)
#
# ValueError: SQL returned 0 rows for run_id='test_spc_time_series_min' job_id='cnc01_vibration_spc_all_flags' filters={'entity_group': 'ARM', 'entity': 'CNC01', 'sensor': 'vibration_rms', 'start_ts': None, 'end_ts': None} sql_template=entity_sensor_history
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 5
#       1 # ---- Execute one run ----
#       3 from runner.run_one_run import run_one_run
# ----> 5 run_dir = run_one_run(run_plan, PROJECT_ROOT)
#       6 print("Run directory:", run_dir)
#
# File ~/anaconda_projects/GitHub/agentic-predictive-maintenance/runner/run_one_run.py:210, in run_one_run(plan, project_root)
#     208         except Exception as e:
#     209             job_id = job.get("job_id", f"<missing job_id at jobs[{idx}]>")
# --> 210             raise RuntimeError(
#     211                 f"Run failed: run_id={plan.get('run_id')} job_id={job_id} "
#     212                 f"(jobs[{idx}]) error={type(e).__name__}: {e}"
#     213             ) from e
#     214 finally:
#     215     con.close()
#
# RuntimeError: Run failed: run_id=test_spc_time_series_min job_id=cnc01_vibration_spc_all_flags (jobs[0]) error=ValueError: SQL returned 0 rows for run_id='test_spc_time_series_min' job_id='cnc01_vibration_spc_all_flags' filters={'entity_group': 'ARM', 'entity': 'CNC01', 'sensor': 'vibration_rms', 'start_ts': None, 'end_ts': None} sql_template=entity_sensor_history
