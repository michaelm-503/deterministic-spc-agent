# %%
import json
import random
from pathlib import Path
import sys
from IPython.display import Image, display
import time
import pandas as pd

# ---- Project root setup ----

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# ---- Set plan filename ----

plan_filename = "test_exhaustive.json"
plan_lib = json.loads((PROJECT_ROOT / "planner" / plan_filename).read_text())

# %%
# ---- 0) Validate entire JSON library (optional) ----

from runner.validate_plan import validate_plan_library

validate_plan_library(plan_lib)
print("✅ Plan library validated")
# Out:
# ✅ Plan library validated

# %%
# ---- 1) Loop through the whole JSON ----

runs = plan_lib["runs"]

from runner.run_one_run import run_one_run


for run_idx, run_plan in enumerate(runs):
    time.sleep(1)

    # ---- Run Info ----
    print("\n" + "=" * 80)
    print(f"Selected run_idx={run_idx}, run_id={run_plan.get('run_id')}")
    print("request_text:", run_plan.get("request_text"))
    print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
    print("=" * 80)

    # ---- Execute Run ----
    run_dir = run_one_run(run_plan, PROJECT_ROOT)
    print("Run directory:", run_dir)

    # ---- Display Artifacts ----
    for job in run_plan.get("jobs", []):
        job_id = job["job_id"]
        job_dir = run_dir / job_id

        print("\n--- Job:", job_id, "---")

        outputs = job.get("outputs", {})

        # Display Plots
        for plot_spec in outputs.get("plots", []):
            plot_name = plot_spec["plot_name"]
            plot_path = job_dir / plot_name

            print("Plot:", plot_path)

            if plot_path.exists():
                display(Image(filename=str(plot_path)))
            else:
                print("  (missing plot file)")

        # Display Tables
        for table_spec in outputs.get("tables", []):
            table_name = table_spec["table_name"]
            table_path = job_dir / table_name

            print("Table:", table_path)

            if table_path.exists():
                try:
                    df_table = pd.read_csv(table_path)
                    display(df_table)
                except Exception as e:
                    print(f"  (failed to read table: {e})")
            else:
                print("  (missing table file)")
# Out:
# ================================================================================
# Selected run_idx=0, run_id=test_spc_time_series_axis_limits
# request_text: TEST: spc_time_series. Set x_min/x_max, y_min/y_max
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-33
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-33/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=1, run_id=test_spc_time_series_min
# request_text: TEST: spc_time_series plot. minimum request.
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-35
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-35/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=2, run_id=test_spc_time_series_ewma
# request_text: TEST: EWMA alpha override.
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-36
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-36/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=3, run_id=test_spc_time_series_window
# request_text: TEST: spc_time_series plot. Set window_days.
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-37
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-37/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=4, run_id=test_spc_time_series_legend
# request_text: TEST: spc_time_series plot. Hide legend
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-38
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-38/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=5, run_id=test_spc_time_series_limits
# request_text: TEST: spc_time_series plot. Hide limits
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-39
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-39/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=6, run_id=test_spc_time_series_ewma
# request_text: TEST: spc_time_series plot. Hide ewma
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-40
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-40/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=7, run_id=test_spc_time_series_points
# request_text: TEST: spc_time_series plot. Hide datapoints
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-41
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-41/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=8, run_id=test_fleet_time_trend_all_flags
# request_text: TEST: fleet_time_trend plot. Validate flags (show_raw/show_ewma/show_limits/legend + window_days + x/y bounds).
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-43
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-43/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=9, run_id=test_fleet_time_trend_axis_limits
# request_text: TEST: fleet_time_trend plot. x/y bounds.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-44
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-44/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=10, run_id=test_fleet_time_trend_window
# request_text: TEST: fleet_time_trend plot. Window days.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-45
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-45/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=11, run_id=test_fleet_time_trend_legend
# request_text: TEST: fleet_time_trend plot. Hide legend.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-46
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-46/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=12, run_id=test_fleet_time_trend_limits
# request_text: TEST: fleet_time_trend plot. Hide limits.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-47
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-47/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=13, run_id=test_fleet_time_trend_ewma
# request_text: TEST: fleet_time_trend plot. Hide ewma.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-49
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-49/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=14, run_id=test_fleet_time_trend_points
# request_text: TEST: fleet_time_trend plot. Hide datapoints.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-50
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-50/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=15, run_id=test_fleet_time_trend_min
# request_text: TEST: fleet_time_trend plot. Min request.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-51
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-51/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=16, run_id=test_fleet_boxplot_all_flags
# request_text: TEST: fleet_boxplot plot. Validate show_limits, legend, window slicing, and y bounds. (x bounds generally not meaningful for boxplot but included for parser robustness).
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-53
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-53/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=17, run_id=test_fleet_boxplot_weird_x_axis
# request_text: TEST: fleet_boxplot plot. Broken x_min/max.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-54
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-54/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=18, run_id=test_fleet_boxplot_window
# request_text: TEST: fleet_boxplot plot. Window slicing
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-55
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-55/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=19, run_id=test_fleet_boxplot_legend
# request_text: TEST: fleet_boxplot plot. legend on.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-56
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-56/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=20, run_id=test_fleet_boxplot_limits
# request_text: TEST: fleet_boxplot plot. Hide limits.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-57
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-57/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=21, run_id=test_fleet_boxplot_min
# request_text: TEST: fleet_boxplot plot. min request.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-58
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-07-58/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=22, run_id=test_fleet_ooc_summary_table
# request_text: TEST: fleet_ooc_summary table. Validate table generation and time slicing parameters. %OOC computed from RAW value.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-00
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-00/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_3_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         121.0         0.0     0.000000
# 1          CNC  vibration_rms  CNC02         122.0         0.0     0.000000
# 2          CNC  vibration_rms  CNC03         128.0         0.0     0.000000
# 3          CNC  vibration_rms  CNC04         118.0        20.0    16.949153
# 4          CNC  vibration_rms  CNC05         130.0         0.0     0.000000
# ================================================================================
# Selected run_idx=23, run_id=test_fleet_ooc_summary_table_min
# request_text: TEST: fleet_ooc_summary table. No params.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-01
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-01/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_3_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         554.0        19.0     3.429603
# 1          CNC  vibration_rms  CNC02         509.0        21.0     4.125737
# 2          CNC  vibration_rms  CNC03         572.0        17.0     2.972028
# 3          CNC  vibration_rms  CNC04         523.0        21.0     4.015296
# 4          CNC  vibration_rms  CNC05         556.0         1.0     0.179856
# ================================================================================
# Selected run_idx=24, run_id=test_fleet_ooc_summary_1day
# request_text: TEST: fleet_ooc_summary table. 1 day.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-02
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-02/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_3_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01          36.0         0.0          0.0
# 1          CNC  vibration_rms  CNC02          42.0         0.0          0.0
# 2          CNC  vibration_rms  CNC03          36.0         0.0          0.0
# 3          CNC  vibration_rms  CNC04          48.0         0.0          0.0
# 4          CNC  vibration_rms  CNC05          41.0         0.0          0.0
# ================================================================================
# Selected run_idx=25, run_id=test_fleet_ooc_summary_400days
# request_text: TEST: fleet_ooc_summary table. 400 days.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-03
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-08-03/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_3_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         554.0        19.0     3.429603
# 1          CNC  vibration_rms  CNC02         509.0        21.0     4.125737
# 2          CNC  vibration_rms  CNC03         572.0        17.0     2.972028
# 3          CNC  vibration_rms  CNC04         523.0        21.0     4.015296
# 4          CNC  vibration_rms  CNC05         556.0         1.0     0.179856
