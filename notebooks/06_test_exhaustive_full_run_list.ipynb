# %%
import json
import random
from pathlib import Path
import sys
from IPython.display import Image, display
import time
import pandas as pd

# ---- Project root setup ----

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# ---- Set plan filename ----

plan_filename = "test_exhaustive.json"
plan_lib = json.loads((PROJECT_ROOT / "planner" / plan_filename).read_text())

# %%
# ---- 0) Validate entire JSON library (optional) ----

from runner.validate_plan import validate_plan_library

validate_plan_library(plan_lib)
print("✅ Plan library validated")
# Out:
# ✅ Plan library validated

# %%
# ---- 1) Loop through the whole JSON ----

runs = plan_lib["runs"]

from runner.run_one_run import run_one_run


for run_idx, run_plan in enumerate(runs):
    time.sleep(1)

    # ---- Run Info ----
    print("\n" + "=" * 80)
    print(f"Selected run_idx={run_idx}, run_id={run_plan.get('run_id')}")
    print("request_text:", run_plan.get("request_text"))
    print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
    print("=" * 80)

    # ---- Execute Run ----
    run_dir = run_one_run(run_plan, PROJECT_ROOT)
    print("Run directory:", run_dir)

    # ---- Display Artifacts ----
    for job in run_plan.get("jobs", []):
        job_id = job["job_id"]
        job_dir = run_dir / job_id

        print("\n--- Job:", job_id, "---")

        outputs = job.get("outputs", {})

        # Display Plots
        for plot_spec in outputs.get("plots", []):
            plot_name = plot_spec["plot_name"]
            plot_path = job_dir / plot_name

            print("Plot:", plot_path)

            if plot_path.exists():
                display(Image(filename=str(plot_path)))
            else:
                print("  (missing plot file)")

        # Display Tables
        for table_spec in outputs.get("tables", []):
            table_name = table_spec["table_name"]
            table_path = job_dir / table_name

            print("Table:", table_path)

            if table_path.exists():
                try:
                    df_table = pd.read_csv(table_path)
                    display(df_table)
                except Exception as e:
                    print(f"  (failed to read table: {e})")
            else:
                print("  (missing table file)")
# Out:
# ================================================================================
# Selected run_idx=0, run_id=test_spc_time_series_min
# request_text: TEST: Single entity time trend. Minimum request.
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-33
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-33/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=1, run_id=test_spc_time_series_ewma
# request_text: TEST: Single entity time trend. EWMA alpha override.
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-35
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-35/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=2, run_id=test_spc_time_series_axis_limits
# request_text: TEST: Single entity time trend. Set x_min/x_max, y_min/y_max
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-36
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-36/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=3, run_id=test_spc_time_series_window
# request_text: TEST: Single entity time trend. Set window_days.
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-37
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-37/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=4, run_id=test_spc_time_series_legend
# request_text: TEST: Single entity time trend. Hide legend
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-38
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-38/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=5, run_id=test_spc_time_series_limits
# request_text: TEST: Single entity time trend. Hide limits
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-39
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-39/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=6, run_id=test_spc_time_series_ewma
# request_text: TEST: Single entity time trend. Hide EWMA
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-40
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-40/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=7, run_id=test_spc_time_series_points
# request_text: TEST: Single entity time trend. Hide datapoints
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-42
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-42/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=8, run_id=test_spc_time_series_points
# request_text: TEST: Single entity time trend. Bad param
# jobs: ['cnc01_vibration_spc_all_flags']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-43
#
# --- Job: cnc01_vibration_spc_all_flags ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-43/cnc01_vibration_spc_all_flags/cnc01_vibration_spc_all_flags.png
# ================================================================================
# Selected run_idx=9, run_id=test_fleet_time_trend_all_flags
# request_text: TEST: Fleet time trend. Validate all flags.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-44
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-44/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=10, run_id=test_fleet_time_trend
# request_text: TEST: Fleet time trend. Specify entity SQL filter.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-45
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-45/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=11, run_id=test_fleet_time_trend_axis_limits
# request_text: TEST: Fleet time trend. Set x/y bounds.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-46
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-46/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=12, run_id=test_fleet_time_trend_window
# request_text: TEST: Fleet time trend. Set window_days.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-48
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-48/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=13, run_id=test_fleet_time_trend_legend
# request_text: TEST: Fleet time trend. Hide legend.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-49
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-49/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=14, run_id=test_fleet_time_trend_limits
# request_text: TEST: Fleet time trend. Hide limits.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-50
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-50/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=15, run_id=test_fleet_time_trend_ewma
# request_text: TEST: Fleet time trend. Hide EWMA, Show datapoints.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-51
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-51/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=16, run_id=test_fleet_time_trend_points
# request_text: TEST: Fleet time trend. Show datapoints and EWMA.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-53
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-53/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=17, run_id=test_fleet_time_trend_min
# request_text: TEST: Fleet time trend. Min request.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-54
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-54/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=18, run_id=test_fleet_time_trend_min
# request_text: TEST: Fleet time trend. Bad param.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-55
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-55/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=19, run_id=test_fleet_time_trend_min
# request_text: TEST: Fleet time trend. 1 entity filter.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-56
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-56/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=20, run_id=test_fleet_time_trend_min
# request_text: TEST: Fleet time trend. 2 entity filter.
# jobs: ['cnc_fleet_vibration_time_trend']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-58
#
# --- Job: cnc_fleet_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-58/cnc_fleet_vibration_time_trend/cnc_fleet_vibration_time_trend_all_flags.png
# ================================================================================
# Selected run_idx=21, run_id=test_fleet_boxplot_all_flags
# request_text: TEST: Fleet boxplot. Validate all flags.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-59
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-43-59/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=22, run_id=test_fleet_boxplot_x_axis
# request_text: TEST: Fleet boxplot. x_min/max range shouldn't do anything?
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-00
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-00/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=23, run_id=test_fleet_boxplot_window
# request_text: TEST: Fleet boxplot. window_days=1
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-01
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-01/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=24, run_id=test_fleet_boxplot_window
# request_text: TEST: Fleet boxplot. 1 entity filter, window_days=7
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-02
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-02/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=25, run_id=test_fleet_boxplot_window
# request_text: TEST: Fleet boxplot. 2 entity filter, window_days=7
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-03
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-03/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=26, run_id=test_fleet_boxplot_window_ewma
# request_text: TEST: Fleet boxplot. use EWMA. 2 entity filter, window_days=7
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-05
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-05/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=27, run_id=test_fleet_boxplot_legend
# request_text: TEST: Fleet boxplot. legend on.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-06
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-06/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=28, run_id=test_fleet_boxplot_limits
# request_text: TEST: Fleet boxplot. Hide limits.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-07
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-07/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=29, run_id=test_fleet_boxplot_min
# request_text: TEST: Fleet boxplot. min request.
# jobs: ['cnc_fleet_vibration_boxplot']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-08
#
# --- Job: cnc_fleet_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-08/cnc_fleet_vibration_boxplot/cnc_fleet_vibration_boxplot_all_flags.png
# ================================================================================
# Selected run_idx=30, run_id=test_fleet_ooc_summary_table_min
# request_text: TEST: Fleet OOC summary. No params.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-09
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-09/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         554.0        19.0     3.429603
# 1          CNC  vibration_rms  CNC02         509.0        21.0     4.125737
# 2          CNC  vibration_rms  CNC03         572.0        17.0     2.972028
# 3          CNC  vibration_rms  CNC04         523.0        21.0     4.015296
# 4          CNC  vibration_rms  CNC05         556.0         1.0     0.179856
# ================================================================================
# Selected run_idx=31, run_id=test_fleet_ooc_summary_3day
# request_text: TEST: Fleet OOC summary. Last 3 day.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-10
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-10/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_3_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         121.0         0.0     0.000000
# 1          CNC  vibration_rms  CNC02         122.0         0.0     0.000000
# 2          CNC  vibration_rms  CNC03         128.0         0.0     0.000000
# 3          CNC  vibration_rms  CNC04         118.0        20.0    16.949153
# 4          CNC  vibration_rms  CNC05         130.0         0.0     0.000000
# ================================================================================
# Selected run_idx=32, run_id=test_fleet_ooc_summary_ts_filters
# request_text: TEST: Fleet OOC summary. ts filter 1/4-1/7.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-12
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-12/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_1_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         108.0        19.0    17.592593
# 1          CNC  vibration_rms  CNC02          68.0         4.0     5.882353
# 2          CNC  vibration_rms  CNC03         140.0         0.0     0.000000
# 3          CNC  vibration_rms  CNC04         133.0         0.0     0.000000
# 4          CNC  vibration_rms  CNC05         110.0         0.0     0.000000
# ================================================================================
# Selected run_idx=33, run_id=test_fleet_ooc_summary_ts_filters
# request_text: TEST: Fleet OOC summary. ts filter 1/4-1/7. window 1 day.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-13
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-13/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_1_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         108.0        19.0    17.592593
# 1          CNC  vibration_rms  CNC02          68.0         4.0     5.882353
# 2          CNC  vibration_rms  CNC03         140.0         0.0     0.000000
# 3          CNC  vibration_rms  CNC04         133.0         0.0     0.000000
# 4          CNC  vibration_rms  CNC05         110.0         0.0     0.000000
# ================================================================================
# Selected run_idx=34, run_id=test_fleet_ooc_summary_ts_filters
# request_text: TEST: Fleet OOC summary. ts filter 1/6-1/7.
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-14
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-14/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_1_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01          40.0         1.0          2.5
# 1          CNC  vibration_rms  CNC02          39.0         0.0          0.0
# 2          CNC  vibration_rms  CNC03          50.0         0.0          0.0
# 3          CNC  vibration_rms  CNC04          42.0         0.0          0.0
# 4          CNC  vibration_rms  CNC05          43.0         0.0          0.0
# ================================================================================
# Selected run_idx=35, run_id=test_fleet_ooc_summary_ts_filters
# request_text: TEST: Fleet OOC summary. x_min/max filters (bad params).
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-15
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-15/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_1_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         554.0        19.0     3.429603
# 1          CNC  vibration_rms  CNC02         509.0        21.0     4.125737
# 2          CNC  vibration_rms  CNC03         572.0        17.0     2.972028
# 3          CNC  vibration_rms  CNC04         523.0        21.0     4.015296
# 4          CNC  vibration_rms  CNC05         556.0         1.0     0.179856
# ================================================================================
# Selected run_idx=36, run_id=test_fleet_ooc_summary_1day
# request_text: TEST: Fleet OOC summary. Last 7 day. 1 entity filter
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-16
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-16/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_7_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC03         278.0        17.0     6.115108
# ================================================================================
# Selected run_idx=37, run_id=test_fleet_ooc_summary_1day
# request_text: TEST: Fleet OOC summary. Last 7 day. 2 entity filter
# jobs: ['cnc_fleet_vibration_ooc_table']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-17
#
# --- Job: cnc_fleet_vibration_ooc_table ---
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-44-17/cnc_fleet_vibration_ooc_table/cnc_fleet_vibration_ooc_last_7_days.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         288.0         0.0     0.000000
# 1          CNC  vibration_rms  CNC03         278.0        17.0     6.115108
