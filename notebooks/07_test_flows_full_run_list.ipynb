# %%
import json
import random
from pathlib import Path
import sys
from IPython.display import Image, display
import time
import pandas as pd

# ---- Project root setup ----

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# ---- Set plan filename ----

plan_filename = "test_flows.json"
plan_lib = json.loads((PROJECT_ROOT / "planner" / plan_filename).read_text())

# %%
# ---- 0) Validate entire JSON library (optional) ----

from runner.validate_plan import validate_plan_library

validate_plan_library(plan_lib)
print("✅ Plan library validated")
# Out:
# ✅ Plan library validated

# %%
# ---- 1) Loop through the whole JSON ----

runs = plan_lib["runs"]

from runner.run_one_run import run_one_run


for run_idx, run_plan in enumerate(runs):
    time.sleep(1)

    # ---- Run Info ----
    print("\n" + "=" * 80)
    print(f"Selected run_idx={run_idx}, run_id={run_plan.get('run_id')}")
    print("request_text:", run_plan.get("request_text"))
    print("jobs:", [j.get("job_id") for j in run_plan.get("jobs", [])])
    print("=" * 80)

    # ---- Execute Run ----
    run_dir = run_one_run(run_plan, PROJECT_ROOT)
    print("Run directory:", run_dir)

    # ---- Display Artifacts ----
    for job in run_plan.get("jobs", []):
        job_id = job["job_id"]
        job_dir = run_dir / job_id

        print("\n--- Job:", job_id, "---")

        outputs = job.get("outputs", {})

        # Display Plots
        for plot_spec in outputs.get("plots", []):
            plot_name = plot_spec["plot_name"]
            plot_path = job_dir / plot_name

            print("Plot:", plot_path)

            if plot_path.exists():
                display(Image(filename=str(plot_path)))
            else:
                print("  (missing plot file)")

        # Display Tables
        for table_spec in outputs.get("tables", []):
            table_name = table_spec["table_name"]
            table_path = job_dir / table_name

            print("Table:", table_path)

            if table_path.exists():
                try:
                    df_table = pd.read_csv(table_path)
                    display(df_table)
                except Exception as e:
                    print(f"  (failed to read table: {e})")
            else:
                print("  (missing table file)")
# Out:
# ================================================================================
# Selected run_idx=0, run_id=test_multi_jobs_and_mixed_outputs
# request_text: TEST: multi-job run. Mix fleet plots, fleet table, and a single-entity add-on plot in the same run.
# jobs: ['fleet_cnc_vibration_time_trend', 'fleet_cnc_vibration_boxplot', 'single_entity_add_on_cnc01']
# ================================================================================
# /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/plots/fleet_time_trend.py:120: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="best")
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44
#
# --- Job: fleet_cnc_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_time_trend_all_limits_off.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_time_trend_7_legend_off.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_time_trend_3_points_on.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_time_trend_1_ewma_off.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_time_trend_7_cnc01.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_time_trend_7_cnc01_cnc02.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_boxplot_3_raw_true.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_boxplot_1_limits_off.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_boxplot_7_cnc03.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_boxplot_7_cnc01_cnc03.png
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_ooc_summary_3.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         121.0         0.0     0.000000
# 1          CNC  vibration_rms  CNC02         122.0         0.0     0.000000
# 2          CNC  vibration_rms  CNC03         128.0         0.0     0.000000
# 3          CNC  vibration_rms  CNC04         118.0        20.0    16.949153
# 4          CNC  vibration_rms  CNC05         130.0         0.0     0.000000
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_ooc_summary_1.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01          36.0         0.0          0.0
# 1          CNC  vibration_rms  CNC02          42.0         0.0          0.0
# 2          CNC  vibration_rms  CNC03          36.0         0.0          0.0
# 3          CNC  vibration_rms  CNC04          48.0         0.0          0.0
# 4          CNC  vibration_rms  CNC05          41.0         0.0          0.0
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_ooc_summary_7_cnc03.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC03         278.0        17.0     6.115108
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_time_trend/fleet_ooc_summary_7_cnc01_cnc03.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         288.0         0.0     0.000000
# 1          CNC  vibration_rms  CNC03         278.0        17.0     6.115108
# --- Job: fleet_cnc_vibration_boxplot ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/fleet_cnc_vibration_boxplot/fleet_boxplot.png
# --- Job: single_entity_add_on_cnc01 ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-44/single_entity_add_on_cnc01/cnc01_zoom.png
# ================================================================================
# Selected run_idx=1, run_id=test_filename_collision_handling
# request_text: TEST: collision handling. Same plot_name and table_name repeated in one job; runner should de-dupe by appending _#.
# jobs: ['collision_job']
# ================================================================================
# Run directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-46
#
# --- Job: collision_job ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-46/collision_job/collision.png
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-46/collision_job/collision.png
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-46/collision_job/collision.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         123.0         0.0          0.0
# Table: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-26T15-42-46/collision_job/collision.csv
#   entity_group         sensor entity  total_points  ooc_points  percent_ooc
# 0          CNC  vibration_rms  CNC01         123.0         0.0          0.0

# %%
# ---- Set plan filename ---- REPLOT ----

plan_filename = "test_replot.json"
plan_lib = json.loads((PROJECT_ROOT / "planner" / plan_filename).read_text())

# %%
# ---- 0) Validate entire JSON library (optional) ----

from runner.replot_run import replot_from_plan

replot_dir_output = replot_from_plan(plan_lib, PROJECT_ROOT)

# --- Display artifacts ---
for replot_dir in replot_dir_output:
    print("Replot directory:", replot_dir)
    for job in plan_lib.get("jobs", []):
        job_id = job["job_id"]
    
        print("\n--- Replot Job:", job_id, "---")
    
        outputs = job.get("outputs", {})
    
        # Plots
        for plot_spec in outputs.get("plots", []):
            plot_path = replot_dir / plot_spec["plot_name"]
            print("Plot:", plot_path)
            if plot_path.exists():
                display(Image(filename=str(plot_path)))
            else:
                print("  (missing plot file)")
    
        # Tables
        for table_spec in outputs.get("tables", []):
            table_path = replot_dir / table_spec["table_name"]
            print("Table:", table_path)
            if table_path.exists():
                display(pd.read_csv(table_path))
            else:
                print("  (missing table file)")
# Out:
# Replot directory: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-19-55/fleet_cnc_vibration_time_trend/replots/2026-02-26T15-42-46
#
# --- Replot Job: fleet_cnc_vibration_time_trend ---
# Plot: /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-02-25T22-19-55/fleet_cnc_vibration_time_trend/replots/2026-02-26T15-42-46/fleet_time_trend_7_cnc01_cnc02_cnc03.png
