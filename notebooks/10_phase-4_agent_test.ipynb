# %%
from pathlib import Path
import sys

# ---- Project root setup ----

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))

# ---- Set plan filename ----

from spc_agent.agent.agent_runner import ask_agent

# %%
result = ask_agent(
    prompt="CPR11 needed maintenance last week due to motor temperature and again due to vibration. How is the tool doing now?",
    project_root=PROJECT_ROOT,
)

print(result.run_dir)
print(result.run_summary_path)
print(result.verification_summary)
# Out:
# Matched planner prompt: CPR11 needed maintenance last week due to motor temperature and again due to vibration. How is the tool doing now?
# /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-03-07T13-01-33
# /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-03-07T13-01-33/run_summary.md
# ✅ All artifacts verified (base + replots).

# %%
result = ask_agent(
    prompt="Show CPR11 motor temperature after maintenance",
    project_root=PROJECT_ROOT,
)

print(result.run_dir)
print(result.run_summary_path)
print(result.verification_summary)
# Out:
# Matched planner prompt: CPR11 needed maintenance last week due to motor temperature and again due to vibration. How is the tool doing now?
# /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-03-07T13-01-43
# /Users/mcmoore/anaconda_projects/GitHub/agentic-predictive-maintenance/runs/2026-03-07T13-01-43/run_summary.md
# ✅ All artifacts verified (base + replots).
